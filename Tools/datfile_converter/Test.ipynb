# %%
import dat_to_json
import importlib
importlib.reload(dat_to_json)
# Out:
# Processing river flow section: 1     2   3.1150                    0.4387        0.00  -9.9      'Reach 1 Cam Bk - source to conf Wellow Bk (Diffuse)'
#
# Processing river flow section: 2     2   2.1707                    0.3587        0.00  -9.9      'Reach 2 Lyde Bk - source to conf Wellow Bk (Diffuse)'
#
# Processing river flow section: 3     2   2.8634                    0.4074        0.00  -9.9      'Reach 3 Kilmersdon Str - source to conf Snails Bk (Diffuse)'
#
# Processing river flow section: 4     2   2.5804                    0.3778        0.00  -9.9      'Reach 4 Snails Bk - source to conf Kilmersdon Str (Diffuse)'
#
# Processing river flow section: 5     2   2.5804                    0.3778        0.00  -9.9      'Reach 5 Snails Bk - source to conf Kilmersdon Str (Diffuse)'
#
# Processing river flow section: 6     2   2.8151                    0.3903        0.00  -9.9      'Reach 6 Wellow Bk - source to conf Snails Bk (Diffuse)'
#
# ...
